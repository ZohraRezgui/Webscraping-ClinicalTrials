# %%
import pandas as pd
from scrapeThisData import ScrapeThatData

# %%
#Instanciate the ScrapeThatData class with a time threshold to wait for the pages to load
cl = ScrapeThatData(time_threshold = 15)

#the condition to search for
condition ='covid-19'

#attributes to show and collect from search page
attributes = ['status',  'nct number', 'age', 'sex', 'phase']

#status of clinical trials
#status = ['recruiting']


#call the main function with the corresponding parameters, the last one stands for the number of studies to collect
results = cl(condition, attributes,listed_states = None, amount_of_data = None) #None for the parameters means we won't filter, we'll take all states and all data there is
# Out:
# Getting data from page 1
# Getting data from page 2
# Getting data from page 3
# WARNING: Number of Participants in Study number NCT04323761 is unavailable
# Collected Data from 100 Studies:
# WARNING: Number of Participants in Study number NCT04288713 is unavailable
# WARNING: Number of Participants in Study number NCT04302766 is unavailable
# Collected Data from 200 Studies:

# %%
df = pd.DataFrame(results[1:], columns=results[0] )

# %%
df.head()
# Out:
#                    status             phase  sex  \
# 0  Active, not recruiting    Not Applicable  All
# 1      Not yet recruiting  Phase 2\nPhase 3  All
# 2              Recruiting    Not Applicable  All
# 3      Not yet recruiting           Phase 4  All
# 4               Withdrawn    Not Applicable  All
#
#                                            age   nct number  \
# 0    18 Years and older   (Adult, Older Adult)  NCT04321421
# 1  18 Years to 75 Years   (Adult, Older Adult)  NCT04291053
# 2  18 Years to 70 Years   (Adult, Older Adult)  NCT04324489
# 3  18 Years to 65 Years   (Adult, Older Adult)  NCT04323228
# 4  18 Years to 80 Years   (Adult, Older Adult)  NCT04287686
#
#                                            inclusion  \
# 0  death [ Time Frame: within 7 days ]death from ...
# 1  Mortality rate [ Time Frame: up to 28 days ]Al...
# 2  Improved clinical status [ Time Frame: Day 14 ...
# 3  Change from baseline score of Nutrition risk s...
# 4  Time course of body temperature (fever) [ Time...
#
#                                            exclusion enrollment
# 0  time to extubation [ Time Frame: within 7 days...         49
# 1  Clinical status assessed according to the offi...        550
# 2  SARS-CoV-2 RNA [ Time Frame: 28 days ]time to ...          4
# 3  Change from baseline Weight at end of the tria...         30
# 4  P/F ratio over time [ Time Frame: 14 days ]PaO...          0

# %%
len(df)
# Out:
# 202

# %%
import matplotlib.pyplot as plt
df['status'].value_counts().plot(kind='bar')

# %%
df['sex'].value_counts().plot(kind='bar')

# %%
df['phase'].value_counts().plot(kind='bar')

# %%
df['age'].value_counts().plot(kind='bar')
